# %%
print("THIS IS PYTHON PROGRAMM")
if True:
    print("This is indented correctly.")
else:
    print("This won't run.")
# Out:
# THIS IS PYTHON PROGRAMM
# This is indented correctly.

# %%
name = "Jyotsna"
age = 19
height = 5.3
grade= 'A'

# Print values
print("Name:", name)
print("Age:", age)
print("Height:", height)
print("grade:",grade)

name = 12
print("New value of name:", name)
# Out:
# Name: Jyotsna
# Age: 19
# Height: 5.3
# grade: A
# New value of name: 12

# %%
a = 1
print(type(a))
# Out:
# <class 'int'>

# %%
b=8.13
print(type(b))
# Out:
# <class 'float'>

# %%
c='python'
d=False
e = [1, 'A', 3.14, "four"]
f = {"name": "JYOTSNA", "age": 12}
print(type(f), f)
print(type(c))
print(type(d))
print(type(e),e)
print(type(f), f)
# Out:
# <class 'dict'> {'name': 'JYOTSNA', 'age': 12}
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 'A', 3.14, 'four']
# <class 'dict'> {'name': 'JYOTSNA', 'age': 12}

# %%
print("This will print ouput on the screen")
# Out:
# This will print ouput on the screen

# %%
college_name= input("Enter your college name: ")
print("my college is" ,college_name)
# Out:
# Enter your college name: bvrit
# my college is bvrit

# %%
age = int(input("Enter your age: "))
print("my age is",age,"now")
# Out:
# Enter your age: 6
# my age is 6 now
