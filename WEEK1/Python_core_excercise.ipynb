# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
DEVICE_TYPES = [
    'Temperature_Sensor',
    'Humidity_Sensor',
    'Pressure_Sensor',
    'Light_Sensor'
]

LOCATIONS = [
    'Lab1',
    'Lab2',
    'OfficeA',
    'OfficeB',
    'Warehouse'
]

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

raw_sensor_data = []

for i in range(1, 101):
    # Timestamp in the format YYYY-MM-DD HH:MM:SS
    timestamp_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Unique device ID
    device_id = f"DEV{i:03d}"

    # Randomly choose device type
    device_type = random.choice(DEVICE_TYPES)

    # Randomly choose location
    location = random.choice(LOCATIONS)

    # Generate random value based on device type
    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    # Create a tuple
    reading = (timestamp_str, device_id, device_type, location, value)

    # Add tuple to the list
    raw_sensor_data.append(reading)

# Print all sensor readings
print("\nGenerated Sensor Readings:")
for reading in raw_sensor_data:
    print(reading)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# Generated Sensor Readings:
# ('2026-07-21 17:13:45', 'DEV001', 'Light_Sensor', 'OfficeB', 175.6)
# ('2026-07-21 17:13:45', 'DEV002', 'Pressure_Sensor', 'OfficeA', 1014.06)
# ('2026-07-21 17:13:45', 'DEV003', 'Temperature_Sensor', 'Lab2', 20.57)
# ('2026-07-21 17:13:45', 'DEV004', 'Temperature_Sensor', 'OfficeB', 22.88)
# ('2026-07-21 17:13:45', 'DEV005', 'Pressure_Sensor', 'Warehouse', 1001.1)
# ('2026-07-21 17:13:45', 'DEV006', 'Light_Sensor', 'OfficeB', 998.23)
# ('2026-07-21 17:13:45', 'DEV007', 'Temperature_Sensor', 'Lab1', 18.58)
# ('2026-07-21 17:13:45', 'DEV008', 'Pressure_Sensor', 'Lab2', 994.08)
# ('2026-07-21 17:13:45', 'DEV009', 'Pressure_Sensor', 'Lab1', 1026.43)
# ('2026-07-21 17:13:45', 'DEV010', 'Pressure_Sensor', 'OfficeA', 1019.57)
# ('2026-07-21 17:13:45', 'DEV011', 'Light_Sensor', 'Lab2', 428.42)
# ('2026-07-21 17:13:45', 'DEV012', 'Pressure_Sensor', 'OfficeA', 993.29)
# ('2026-07-21 17:13:45', 'DEV013', 'Pressure_Sensor', 'Warehouse', 1008.08)
# ('2026-07-21 17:13:45', 'DEV014', 'Pressure_Sensor', 'Lab1', 1020.25)
# ('2026-07-21 17:13:45', 'DEV015', 'Humidity_Sensor', 'Lab2', 65.06)
# ('2026-07-21 17:13:45', 'DEV016', 'Pressure_Sensor', 'Lab2', 1017.1)
# ('2026-07-21 17:13:45', 'DEV017', 'Temperature_Sensor', 'Lab1', 25.91)
# ('2026-07-21 17:13:45', 'DEV018', 'Pressure_Sensor', 'Warehouse', 1024.37)
# ('2026-07-21 17:13:45', 'DEV019', 'Pressure_Sensor', 'OfficeA', 996.21)
# ('2026-07-21 17:13:45', 'DEV020', 'Light_Sensor', 'Lab2', 708.71)
# ('2026-07-21 17:13:45', 'DEV021', 'Pressure_Sensor', 'Lab2', 983.04)
# ('2026-07-21 17:13:45', 'DEV022', 'Light_Sensor', 'Lab2', 630.03)
# ('2026-07-21 17:13:45', 'DEV023', 'Light_Sensor', 'Warehouse', 807.26)
# ('2026-07-21 17:13:45', 'DEV024', 'Temperature_Sensor', 'Lab2', 23.44)
# ('2026-07-21 17:13:45', 'DEV025', 'Pressure_Sensor', 'Lab1', 985.81)
# ('2026-07-21 17:13:45', 'DEV026', 'Light_Sensor', 'Lab1', 736.85)
# ('2026-07-21 17:13:45', 'DEV027', 'Temperature_Sensor', 'OfficeB', 23.91)
# ('2026-07-21 17:13:45', 'DEV028', 'Humidity_Sensor', 'Lab1', 44.37)
# ('2026-07-21 17:13:45', 'DEV029', 'Pressure_Sensor', 'Warehouse', 1014.6)
# ('2026-07-21 17:13:45', 'DEV030', 'Light_Sensor', 'Lab2', 969.25)
# ('2026-07-21 17:13:45', 'DEV031', 'Light_Sensor', 'Lab1', 254.14)
# ('2026-07-21 17:13:45', 'DEV032', 'Temperature_Sensor', 'Lab1', 20.29)
# ('2026-07-21 17:13:45', 'DEV033', 'Temperature_Sensor', 'Lab1', 19.94)
# ('2026-07-21 17:13:45', 'DEV034', 'Light_Sensor', 'OfficeB', 339.72)
# ('2026-07-21 17:13:45', 'DEV035', 'Pressure_Sensor', 'Warehouse', 983.38)
# ('2026-07-21 17:13:45', 'DEV036', 'Humidity_Sensor', 'OfficeA', 64.05)
# ('2026-07-21 17:13:45', 'DEV037', 'Temperature_Sensor', 'OfficeB', 24.21)
# ('2026-07-21 17:13:45', 'DEV038', 'Humidity_Sensor', 'OfficeA', 45.99)
# ('2026-07-21 17:13:45', 'DEV039', 'Temperature_Sensor', 'OfficeB', 21.84)
# ('2026-07-21 17:13:45', 'DEV040', 'Light_Sensor', 'OfficeB', 205.7)
# ('2026-07-21 17:13:45', 'DEV041', 'Light_Sensor', 'OfficeB', 907.65)
# ('2026-07-21 17:13:45', 'DEV042', 'Light_Sensor', 'OfficeA', 893.64)
# ('2026-07-21 17:13:45', 'DEV043', 'Temperature_Sensor', 'Lab1', 24.88)
# ('2026-07-21 17:13:45', 'DEV044', 'Pressure_Sensor', 'Lab2', 992.5)
# ('2026-07-21 17:13:45', 'DEV045', 'Pressure_Sensor', 'Lab2', 1019.84)
# ('2026-07-21 17:13:45', 'DEV046', 'Humidity_Sensor', 'Warehouse', 69.25)
# ('2026-07-21 17:13:45', 'DEV047', 'Pressure_Sensor', 'OfficeA', 1014.24)
# ('2026-07-21 17:13:45', 'DEV048', 'Temperature_Sensor', 'OfficeB', 19.04)
# ('2026-07-21 17:13:45', 'DEV049', 'Pressure_Sensor', 'OfficeB', 1022.07)
# ('2026-07-21 17:13:45', 'DEV050', 'Pressure_Sensor', 'OfficeB', 1028.57)
# ('2026-07-21 17:13:45', 'DEV051', 'Temperature_Sensor', 'Lab1', 26.14)
# ('2026-07-21 17:13:45', 'DEV052', 'Pressure_Sensor', 'Lab1', 996.26)
# ('2026-07-21 17:13:45', 'DEV053', 'Humidity_Sensor', 'OfficeB', 36.92)
# ('2026-07-21 17:13:45', 'DEV054', 'Light_Sensor', 'OfficeB', 601.8)
# ('2026-07-21 17:13:45', 'DEV055', 'Temperature_Sensor', 'Warehouse', 26.97)
# ('2026-07-21 17:13:45', 'DEV056', 'Light_Sensor', 'OfficeB', 507.22)
# ('2026-07-21 17:13:45', 'DEV057', 'Light_Sensor', 'Lab2', 649.09)
# ('2026-07-21 17:13:45', 'DEV058', 'Pressure_Sensor', 'Lab1', 986.94)
# ('2026-07-21 17:13:45', 'DEV059', 'Light_Sensor', 'Warehouse', 927.77)
# ('2026-07-21 17:13:45', 'DEV060', 'Temperature_Sensor', 'Warehouse', 26.9)
# ('2026-07-21 17:13:45', 'DEV061', 'Pressure_Sensor', 'OfficeA', 1011.8)
# ('2026-07-21 17:13:45', 'DEV062', 'Temperature_Sensor', 'Lab2', 27.32)
# ('2026-07-21 17:13:45', 'DEV063', 'Pressure_Sensor', 'OfficeB', 994.44)
# ('2026-07-21 17:13:45', 'DEV064', 'Pressure_Sensor', 'Lab2', 1019.26)
# ('2026-07-21 17:13:45', 'DEV065', 'Light_Sensor', 'OfficeA', 101.95)
# ('2026-07-21 17:13:45', 'DEV066', 'Pressure_Sensor', 'Lab2', 1000.07)
# ('2026-07-21 17:13:45', 'DEV067', 'Pressure_Sensor', 'OfficeB', 985.27)
# ('2026-07-21 17:13:45', 'DEV068', 'Light_Sensor', 'OfficeB', 101.2)
# ('2026-07-21 17:13:45', 'DEV069', 'Pressure_Sensor', 'Lab2', 1007.38)
# ('2026-07-21 17:13:45', 'DEV070', 'Humidity_Sensor', 'Warehouse', 62.44)
# ('2026-07-21 17:13:45', 'DEV071', 'Pressure_Sensor', 'Warehouse', 983.57)
# ('2026-07-21 17:13:45', 'DEV072', 'Pressure_Sensor', 'OfficeA', 1002.16)
# ('2026-07-21 17:13:45', 'DEV073', 'Light_Sensor', 'OfficeA', 285.2)
# ('2026-07-21 17:13:45', 'DEV074', 'Pressure_Sensor', 'Lab2', 1017.43)
# ('2026-07-21 17:13:45', 'DEV075', 'Humidity_Sensor', 'OfficeA', 52.05)
# ('2026-07-21 17:13:45', 'DEV076', 'Humidity_Sensor', 'OfficeA', 31.04)
# ('2026-07-21 17:13:45', 'DEV077', 'Humidity_Sensor', 'Lab1', 60.91)
# ('2026-07-21 17:13:45', 'DEV078', 'Humidity_Sensor', 'OfficeB', 42.96)
# ('2026-07-21 17:13:45', 'DEV079', 'Temperature_Sensor', 'OfficeB', 26.27)
# ('2026-07-21 17:13:45', 'DEV080', 'Light_Sensor', 'Warehouse', 254.16)
# ('2026-07-21 17:13:45', 'DEV081', 'Humidity_Sensor', 'Lab1', 64.01)
# ('2026-07-21 17:13:45', 'DEV082', 'Humidity_Sensor', 'OfficeA', 36.87)
# ('2026-07-21 17:13:45', 'DEV083', 'Light_Sensor', 'OfficeB', 418.78)
# ('2026-07-21 17:13:45', 'DEV084', 'Humidity_Sensor', 'Warehouse', 64.19)
# ('2026-07-21 17:13:45', 'DEV085', 'Humidity_Sensor', 'Warehouse', 76.9)
# ('2026-07-21 17:13:45', 'DEV086', 'Temperature_Sensor', 'Lab2', 28.64)
# ('2026-07-21 17:13:45', 'DEV087', 'Temperature_Sensor', 'Lab2', 26.59)
# ('2026-07-21 17:13:45', 'DEV088', 'Temperature_Sensor', 'Lab2', 19.2)
# ('2026-07-21 17:13:45', 'DEV089', 'Light_Sensor', 'Lab1', 975.78)
# ('2026-07-21 17:13:45', 'DEV090', 'Pressure_Sensor', 'OfficeA', 993.61)
# ('2026-07-21 17:13:45', 'DEV091', 'Humidity_Sensor', 'OfficeA', 67.49)
# ('2026-07-21 17:13:45', 'DEV092', 'Humidity_Sensor', 'Lab1', 62.19)
# ('2026-07-21 17:13:45', 'DEV093', 'Pressure_Sensor', 'OfficeA', 1026.19)
# ('2026-07-21 17:13:45', 'DEV094', 'Temperature_Sensor', 'OfficeB', 21.94)
# ('2026-07-21 17:13:45', 'DEV095', 'Pressure_Sensor', 'Lab2', 992.02)
# ('2026-07-21 17:13:45', 'DEV096', 'Pressure_Sensor', 'OfficeB', 1025.59)
# ('2026-07-21 17:13:45', 'DEV097', 'Light_Sensor', 'OfficeA', 438.02)
# ('2026-07-21 17:13:45', 'DEV098', 'Pressure_Sensor', 'OfficeA', 987.95)
# ('2026-07-21 17:13:45', 'DEV099', 'Pressure_Sensor', 'OfficeB', 994.26)
# ('2026-07-21 17:13:45', 'DEV100', 'Pressure_Sensor', 'Warehouse', 1022.53)

# %%
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temp_dict = {
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        }

        temperature_readings.append(temp_dict)

# Print the temperature readings
print("\nTemperature Readings:")
for temp in temperature_readings:
    print(temp)
# Out:
# Temperature Readings:
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV003', 'location': 'Lab2', 'temperature_celsius': 20.57}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV004', 'location': 'OfficeB', 'temperature_celsius': 22.88}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV007', 'location': 'Lab1', 'temperature_celsius': 18.58}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV017', 'location': 'Lab1', 'temperature_celsius': 25.91}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV024', 'location': 'Lab2', 'temperature_celsius': 23.44}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV027', 'location': 'OfficeB', 'temperature_celsius': 23.91}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV032', 'location': 'Lab1', 'temperature_celsius': 20.29}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV033', 'location': 'Lab1', 'temperature_celsius': 19.94}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV037', 'location': 'OfficeB', 'temperature_celsius': 24.21}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV039', 'location': 'OfficeB', 'temperature_celsius': 21.84}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV043', 'location': 'Lab1', 'temperature_celsius': 24.88}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV048', 'location': 'OfficeB', 'temperature_celsius': 19.04}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV051', 'location': 'Lab1', 'temperature_celsius': 26.14}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV055', 'location': 'Warehouse', 'temperature_celsius': 26.97}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV060', 'location': 'Warehouse', 'temperature_celsius': 26.9}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV062', 'location': 'Lab2', 'temperature_celsius': 27.32}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV079', 'location': 'OfficeB', 'temperature_celsius': 26.27}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV086', 'location': 'Lab2', 'temperature_celsius': 28.64}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV087', 'location': 'Lab2', 'temperature_celsius': 26.59}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV088', 'location': 'Lab2', 'temperature_celsius': 19.2}
# {'timestamp': '2026-07-21 17:13:45', 'device_id': 'DEV094', 'location': 'OfficeB', 'temperature_celsius': 21.94}

# %%
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])   # Index 3 is the location

# Print the unique locations
print("\nUnique Locations:")
print(unique_locations)
# Out:
# Unique Locations:
# {'Lab2', 'Warehouse', 'OfficeA', 'OfficeB', 'Lab1'}

# %%
device_stats = {}

# Initialize the dictionary
for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

# Find the minimum and maximum values for each device type
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    if value < min_value:
        min_value = value

    if value > max_value:
        max_value = value

    device_stats[device_type] = (min_value, max_value)

# Display the results
print("\nDevice Statistics:")
for device, stats in device_stats.items():
    print(device, ":", stats)
# Out:
# Device Statistics:
# Temperature_Sensor : (18.58, 28.64)
# Humidity_Sensor : (31.04, 76.9)
# Pressure_Sensor : (983.04, 1028.57)
# Light_Sensor : (101.2, 998.23)

# %%
sample_string = "PythonProgrammingIsFun"
# Extract elements from the 10th to the 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

# Print the results
print("\nReadings from 10th to 20th (inclusive):")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th reading:")
for reading in sliced_readings_2:
    print(reading)
# Out:
# Readings from 10th to 20th (inclusive):
# ('2026-07-21 17:13:45', 'DEV010', 'Pressure_Sensor', 'OfficeA', 1019.57)
# ('2026-07-21 17:13:45', 'DEV011', 'Light_Sensor', 'Lab2', 428.42)
# ('2026-07-21 17:13:45', 'DEV012', 'Pressure_Sensor', 'OfficeA', 993.29)
# ('2026-07-21 17:13:45', 'DEV013', 'Pressure_Sensor', 'Warehouse', 1008.08)
# ('2026-07-21 17:13:45', 'DEV014', 'Pressure_Sensor', 'Lab1', 1020.25)
# ('2026-07-21 17:13:45', 'DEV015', 'Humidity_Sensor', 'Lab2', 65.06)
# ('2026-07-21 17:13:45', 'DEV016', 'Pressure_Sensor', 'Lab2', 1017.1)
# ('2026-07-21 17:13:45', 'DEV017', 'Temperature_Sensor', 'Lab1', 25.91)
# ('2026-07-21 17:13:45', 'DEV018', 'Pressure_Sensor', 'Warehouse', 1024.37)
# ('2026-07-21 17:13:45', 'DEV019', 'Pressure_Sensor', 'OfficeA', 996.21)
# ('2026-07-21 17:13:45', 'DEV020', 'Light_Sensor', 'Lab2', 708.71)
#
# Every 5th reading:
# ('2026-07-21 17:13:45', 'DEV001', 'Light_Sensor', 'OfficeB', 175.6)
# ('2026-07-21 17:13:45', 'DEV006', 'Light_Sensor', 'OfficeB', 998.23)
# ('2026-07-21 17:13:45', 'DEV011', 'Light_Sensor', 'Lab2', 428.42)
# ('2026-07-21 17:13:45', 'DEV016', 'Pressure_Sensor', 'Lab2', 1017.1)
# ('2026-07-21 17:13:45', 'DEV021', 'Pressure_Sensor', 'Lab2', 983.04)
# ('2026-07-21 17:13:45', 'DEV026', 'Light_Sensor', 'Lab1', 736.85)
# ('2026-07-21 17:13:45', 'DEV031', 'Light_Sensor', 'Lab1', 254.14)
# ('2026-07-21 17:13:45', 'DEV036', 'Humidity_Sensor', 'OfficeA', 64.05)
# ('2026-07-21 17:13:45', 'DEV041', 'Light_Sensor', 'OfficeB', 907.65)
# ('2026-07-21 17:13:45', 'DEV046', 'Humidity_Sensor', 'Warehouse', 69.25)
# ('2026-07-21 17:13:45', 'DEV051', 'Temperature_Sensor', 'Lab1', 26.14)
# ('2026-07-21 17:13:45', 'DEV056', 'Light_Sensor', 'OfficeB', 507.22)
# ('2026-07-21 17:13:45', 'DEV061', 'Pressure_Sensor', 'OfficeA', 1011.8)
# ('2026-07-21 17:13:45', 'DEV066', 'Pressure_Sensor', 'Lab2', 1000.07)
# ('2026-07-21 17:13:45', 'DEV071', 'Pressure_Sensor', 'Warehouse', 983.57)
# ('2026-07-21 17:13:45', 'DEV076', 'Humidity_Sensor', 'OfficeA', 31.04)
# ('2026-07-21 17:13:45', 'DEV081', 'Humidity_Sensor', 'Lab1', 64.01)
# ('2026-07-21 17:13:45', 'DEV086', 'Temperature_Sensor', 'Lab2', 28.64)
# ('2026-07-21 17:13:45', 'DEV091', 'Humidity_Sensor', 'OfficeA', 67.49)
# ('2026-07-21 17:13:45', 'DEV096', 'Pressure_Sensor', 'OfficeB', 1025.59)

# %%
# Extract the substring "Programming"
substring_1 = sample_string[6:17]

# Extract the reverse of "Python" -> "nohtyP"
substring_2 = sample_string[5::-1]

# Print the results
print("\nSubstring 1:", substring_1)
print("Substring 2:", substring_2)
# Out:
# Substring 1: Programming
# Substring 2: nohtyP

# %%
# Access the device_type of the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

# Print the results
print("\n5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Pressure_Sensor
# Device Type Suffix: Sensor

# %%
# 2.1 Function to get readings by location
print("\n--- Task 2: Function Definitions and Usage ---")

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


# Example usage
location = "Lab1"
lab1_readings = get_readings_by_location(raw_sensor_data, location)

print(f"\nSensor Readings for {location}:")
for reading in lab1_readings:
    print(reading)
# Out:
# --- Task 2: Function Definitions and Usage ---
#
# Sensor Readings for Lab1:
# ('2026-07-21 17:13:45', 'DEV007', 'Temperature_Sensor', 'Lab1', 18.58)
# ('2026-07-21 17:13:45', 'DEV009', 'Pressure_Sensor', 'Lab1', 1026.43)
# ('2026-07-21 17:13:45', 'DEV014', 'Pressure_Sensor', 'Lab1', 1020.25)
# ('2026-07-21 17:13:45', 'DEV017', 'Temperature_Sensor', 'Lab1', 25.91)
# ('2026-07-21 17:13:45', 'DEV025', 'Pressure_Sensor', 'Lab1', 985.81)
# ('2026-07-21 17:13:45', 'DEV026', 'Light_Sensor', 'Lab1', 736.85)
# ('2026-07-21 17:13:45', 'DEV028', 'Humidity_Sensor', 'Lab1', 44.37)
# ('2026-07-21 17:13:45', 'DEV031', 'Light_Sensor', 'Lab1', 254.14)
# ('2026-07-21 17:13:45', 'DEV032', 'Temperature_Sensor', 'Lab1', 20.29)
# ('2026-07-21 17:13:45', 'DEV033', 'Temperature_Sensor', 'Lab1', 19.94)
# ('2026-07-21 17:13:45', 'DEV043', 'Temperature_Sensor', 'Lab1', 24.88)
# ('2026-07-21 17:13:45', 'DEV051', 'Temperature_Sensor', 'Lab1', 26.14)
# ('2026-07-21 17:13:45', 'DEV052', 'Pressure_Sensor', 'Lab1', 996.26)
# ('2026-07-21 17:13:45', 'DEV058', 'Pressure_Sensor', 'Lab1', 986.94)
# ('2026-07-21 17:13:45', 'DEV077', 'Humidity_Sensor', 'Lab1', 60.91)
# ('2026-07-21 17:13:45', 'DEV081', 'Humidity_Sensor', 'Lab1', 64.01)
# ('2026-07-21 17:13:45', 'DEV089', 'Light_Sensor', 'Lab1', 975.78)
# ('2026-07-21 17:13:45', 'DEV092', 'Humidity_Sensor', 'Lab1', 62.19)

# %%
# 2.2 Function to calculate average temperature

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return round(average, 2)


# Example usage
avg_temperature = calculate_average_temperature(temperature_readings)

print("\nAverage Temperature:", avg_temperature)
# Out:
# Average Temperature: 23.59

# %%
# 2.3 Function to generate a formatted report line

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"


# Example usage
if len(temperature_readings) > 0:
    report = generate_report_line(temperature_readings[0])
    print("\nReport Line:")
    print(report)
# Out:
# Report Line:
# [2026-07-21 17:13:45] Device DEV003 at Lab2: 20.57°C

# %%
# 3.1 Use the os module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.
print("\n--- Task 3: Core Library Usage ---")


reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.

# %%
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string timestamps to datetime objects
    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    # Calculate duration
    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 0 minutes.

# %%
# 3.3 Generate a list of 5 random integers between 100 and 200 (inclusive)

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("\nRandom Values:")
print(random_values)
# Out:
# Random Values:
# [120, 181, 143, 167, 155]
